# %% [markdown]
# # Data Cleaing in Python

# %%
# Importing Libraries

import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading or Reading the File

# %%
df = pd.read_csv('unclean_data.txt')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15520/1776465975.py in <module>
# ----> 1 df = pd.read_csv('unclean_data.txt')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df = pd.read_csv('unclean_data.txt',encoding='unicode_escape')  # Read the Data

# %%
df.shape
# Out:
# (14, 16)

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %% [markdown]
# ### Data Type Inconsistencies

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df.gross.dtypes
# Out:
# dtype('int64')

# %%
# ?df.astype

# %%
df.gross.astype(float).dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### Inconsistent Column Names

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.columns.str.upper()
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.columns = df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['MOVIE_TITLE', 'NUM_CRITIC_FOR_REVIEWS', 'DURATION',
#        'DIRECTOR_FACEBOOK_LIKES', 'ACTOR_3_FACEBOOK_LIKES',
#        'ACTOR_1_FACEBOOK_LIKES', 'GROSS', 'NUM_VOTED_USERS',
#        'CAST_TOTAL_FACEBOOK_LIKES', 'FACENUMBER_IN_POSTER',
#        'NUM_USER_FOR_REVIEWS', 'BUDGET', 'TITLE_YEAR',
#        'ACTOR_2_FACEBOOK_LIKES', 'IMDB_SCORE', 'TITLE_YEAR.1'],
#       dtype='object')

# %%
# Cleaning movie_title
df['MOVIE_TITLE'] = df['MOVIE_TITLE'].str.split('?').str[0]

# %%
df.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS  DURATION  \
# 0                                    Avatar                     723     178.0
# 1  Pirates of the Caribbean: At World's End                     302       NaN
# 2                                   Spectre                     602     148.0
# 3                     The Dark Knight Rises                     813       NaN
# 4                               John Carter                     462     132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
# ...

# %% [markdown]
# ### Renaming columns

# %%
df.rename(columns= {'DURATION':'TIME'}, inplace=True)

# %% [markdown]
# ### Missing Data

# %%
df.isnull()
# Out:
#     MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  DIRECTOR_FACEBOOK_LIKES  \
# 0         False                   False  False                    False
# 1         False                   False   True                    False
# 2         False                   False  False                    False
# 3         False                   False   True                    False
# 4         False                   False  False                    False
# 5         False                   False  False                    False
# 6         False                   False   True                    False
# 7         False                   False  False                    False
# 8         False                   False  False                    False
# 9         False                   False  False                    False
# 10        False                   False  False                     True
# 11        False                   False  False                     True
# ...

# %%
df.isnull().any()
# Out:
# MOVIE_TITLE                  False
# NUM_CRITIC_FOR_REVIEWS       False
# TIME                          True
# DIRECTOR_FACEBOOK_LIKES       True
# ACTOR_3_FACEBOOK_LIKES       False
# ACTOR_1_FACEBOOK_LIKES       False
# GROSS                        False
# NUM_VOTED_USERS               True
# CAST_TOTAL_FACEBOOK_LIKES     True
# FACENUMBER_IN_POSTER          True
# NUM_USER_FOR_REVIEWS         False
# BUDGET                       False
# TITLE_YEAR                   False
# ACTOR_2_FACEBOOK_LIKES        True
# IMDB_SCORE                   False
# TITLE_YEAR.1                  True
# dtype: bool

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# MOVIE_TITLE                  0
# NUM_CRITIC_FOR_REVIEWS       0
# TIME                         3
# DIRECTOR_FACEBOOK_LIKES      2
# ACTOR_3_FACEBOOK_LIKES       0
# ACTOR_1_FACEBOOK_LIKES       0
# GROSS                        0
# NUM_VOTED_USERS              1
# CAST_TOTAL_FACEBOOK_LIKES    2
# FACENUMBER_IN_POSTER         5
# NUM_USER_FOR_REVIEWS         0
# BUDGET                       0
# TITLE_YEAR                   0
# ACTOR_2_FACEBOOK_LIKES       1
# IMDB_SCORE                   0
# TITLE_YEAR.1                 7
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 21

# %% [markdown]
# ### Adding a default value or filling the missing data

# %%
df.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar                     723  178.0
# 1  Pirates of the Caribbean: At World's End                     302    NaN
# 2                                   Spectre                     602  148.0
# 3                     The Dark Knight Rises                     813    NaN
# 4                               John Carter                     462  132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
#        GROSS  NUM_VOTED_USERS  CAST_TOTAL_FACEBOOK_LIKES  \
# ...

# %%
# Filling the missing data with 0
df_with_0 = df.fillna(0)

# %%
df_with_0.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar                     723  178.0
# 1  Pirates of the Caribbean: At World's End                     302    0.0
# 2                                   Spectre                     602  148.0
# 3                     The Dark Knight Rises                     813    0.0
# 4                               John Carter                     462  132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
#        GROSS  NUM_VOTED_USERS  CAST_TOTAL_FACEBOOK_LIKES  \
# ...

# %%
# Filling missing data with mean
df['TIME'].mean()
# Out:
# 150.72727272727272

# %%
df_with_mean = df.TIME.fillna(df['TIME'].mean())

# %%
df_with_mean
# Out:
# 0     178.000000
# 1     150.727273
# 2     148.000000
# 3     150.727273
# 4     132.000000
# 5     156.000000
# 6     150.727273
# 7     141.000000
# 8     141.000000
# 9     153.000000
# 10    183.000000
# 11    169.000000
# 12    106.000000
# 13    151.000000
# Name: TIME, dtype: float64

# %% [markdown]
# ### Droping NA

# %%
df.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar                     723  178.0
# 1  Pirates of the Caribbean: At World's End                     302    NaN
# 2                                   Spectre                     602  148.0
# 3                     The Dark Knight Rises                     813    NaN
# 4                               John Carter                     462  132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
#        GROSS  NUM_VOTED_USERS  CAST_TOTAL_FACEBOOK_LIKES  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 21

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop = df.dropna()

# %%
df_drop.shape
# Out:
# (4, 16)

# %%
df_drop.head()
# Out:
#                                    MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 2                                      Spectre                     602  148.0
# 8                      Avengers: Age of Ultron                     635  141.0
# 12                           Quantum of Solace                     403  106.0
# 13  Pirates of the Caribbean: Dead Man's Chest                     313  151.0
#
#    DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 2                       20                     161                   11000
# 8                       10                   19000                   26000
# 12                     395                     393                     451
# 13                     563                    1000                   40000
#
#         GROSS  NUM_VOTED_USERS  CAST_TOTAL_FACEBOOK_LIKES  \
# 2   200074175         275868.0                    11700.0
# 8   458991599         462669.0                    92000.0
# ...

# %%
# ?df.dropna

# %%
df_drop_with_condition = df.dropna(thresh=2)

# %%
df_drop_with_condition.shape
# Out:
# (14, 16)

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_column =df.dropna(axis=1)

# %%
df_drop_column.shape
# Out:
# (14, 9)

# %% [markdown]
# ### Droping Duplicates

# %%
df.head()
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar                     723  178.0
# 1  Pirates of the Caribbean: At World's End                     302    NaN
# 2                                   Spectre                     602  148.0
# 3                     The Dark Knight Rises                     813    NaN
# 4                               John Carter                     462  132.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# 0                      10                     855                    1000
# 1                     563                    1000                   40000
# 2                      20                     161                   11000
# 3                   22000                   23000                   27000
# 4                   "475"                     530                     640
#
#        GROSS  NUM_VOTED_USERS  CAST_TOTAL_FACEBOOK_LIKES  \
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.duplicated('MOVIE_TITLE')
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df.head(10)
# Out:
#                                 MOVIE_TITLE  NUM_CRITIC_FOR_REVIEWS   TIME  \
# 0                                    Avatar                     723  178.0
# 1  Pirates of the Caribbean: At World's End                     302    NaN
# 2                                   Spectre                     602  148.0
# 3                     The Dark Knight Rises                     813    NaN
# 4                               John Carter                     462  132.0
# 5                              Spider-Man 3                     392  156.0
# 6                                   Tangled                     324    NaN
# 7                   Avengers: Age of Ultron                     635  141.0
# 8                   Avengers: Age of Ultron                     635  141.0
# 9    Harry Potter and the Half-Blood Prince                     375  153.0
#
#   DIRECTOR_FACEBOOK_LIKES  ACTOR_3_FACEBOOK_LIKES  ACTOR_1_FACEBOOK_LIKES  \
# ...

# %%
df.shape
# Out:
# (14, 16)

# %%
df_drop_dup = df.drop_duplicates('MOVIE_TITLE')

# %%
df_drop_dup.shape
# Out:
# (13, 16)
